# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=24)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(24,4), index=dates,columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.171542  0.085687 -0.791265  1.843809
# 2013-01-02 -1.027656 -0.570549 -0.028820 -0.772222
# 2013-01-03 -0.604392  0.599069  0.649404 -0.882147
# 2013-01-04 -2.774914  2.075397  0.220806 -2.768576
# 2013-01-05 -0.007489  0.158310 -0.535388 -0.651929
# 2013-01-06 -0.241826 -1.173417 -0.718901 -0.792095
# 2013-01-07  0.773383 -1.823587 -0.483984 -0.096229
# 2013-01-08  1.073535 -0.285984  0.972434 -1.099351
# 2013-01-09  0.974921 -0.000657  0.734197  0.991177
# 2013-01-10 -1.164131 -0.791354  0.245642  0.154251
# 2013-01-11  0.468494  0.146104  0.740764 -0.769460
# 2013-01-12  0.429735  0.425102 -0.063678  1.295333
# 2013-01-13  1.000665  0.341859  1.055143 -1.302456
# 2013-01-14 -0.268342  0.005814 -1.293446 -0.533839
# 2013-01-15  0.624493  0.504429  1.375158 -0.460327
# 2013-01-16 -0.287601  0.687064  0.525610 -1.809233
# 2013-01-17  0.656268 -0.196738  0.340256  0.581416
# ...

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.171542  0.085687 -0.791265  1.843809
# 2013-01-02 -1.027656 -0.570549 -0.028820 -0.772222
# 2013-01-03 -0.604392  0.599069  0.649404 -0.882147
# 2013-01-04 -2.774914  2.075397  0.220806 -2.768576
# 2013-01-05 -0.007489  0.158310 -0.535388 -0.651929

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-22  1.834391 -1.795508 -0.590795  1.211769
# 2013-01-23  0.366789  0.954576  0.160621 -0.419370
# 2013-01-24  0.490921 -0.981180  0.101064  1.213298

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.to_numpy()
# Out:
# array([[-1.71541514e-01,  8.56871119e-02, -7.91264536e-01,
#          1.84380930e+00],
#        [-1.02765581e+00, -5.70548827e-01, -2.88203919e-02,
#         -7.72222005e-01],
#        [-6.04392242e-01,  5.99068987e-01,  6.49404143e-01,
#         -8.82146624e-01],
#        [-2.77491361e+00,  2.07539714e+00,  2.20805982e-01,
#         -2.76857569e+00],
#        [-7.48891002e-03,  1.58309690e-01, -5.35388040e-01,
#         -6.51929348e-01],
#        [-2.41826488e-01, -1.17341729e+00, -7.18900718e-01,
#         -7.92095046e-01],
#        [ 7.73383393e-01, -1.82358656e+00, -4.83983904e-01,
#         -9.62290775e-02],
#        [ 1.07353489e+00, -2.85984218e-01,  9.72434405e-01,
#         -1.09935086e+00],
#        [ 9.74920576e-01, -6.56641173e-04,  7.34197179e-01,
#          9.91177377e-01],
#        [-1.16413116e+00, -7.91354225e-01,  2.45641572e-01,
#          1.54250592e-01],
#        [ 4.68494203e-01,  1.46103675e-01,  7.40764173e-01,
#         -7.69460444e-01],
# ...

# %%
df_empty = pd.DataFrame()

# %%
df.describe()
# Out:
#                A          B          C          D
# count  24.000000  24.000000  24.000000  24.000000
# mean    0.144446  -0.055121   0.085492  -0.257555
# std     0.944133   0.897679   0.868507   1.129975
# min    -2.774914  -1.823587  -1.555579  -2.768576
# 25%    -0.273157  -0.625750  -0.549240  -0.936448
# 50%     0.398262   0.045751   0.130842  -0.497083
# 75%     0.784611   0.444934   0.670602   0.652452
# max     1.834391   2.075397   2.105619   1.843809

# %%
df["A"]
# Out:
# 2013-01-01   -0.171542
# 2013-01-02   -1.027656
# 2013-01-03   -0.604392
# 2013-01-04   -2.774914
# 2013-01-05   -0.007489
# 2013-01-06   -0.241826
# 2013-01-07    0.773383
# 2013-01-08    1.073535
# 2013-01-09    0.974921
# 2013-01-10   -1.164131
# 2013-01-11    0.468494
# 2013-01-12    0.429735
# 2013-01-13    1.000665
# 2013-01-14   -0.268342
# 2013-01-15    0.624493
# 2013-01-16   -0.287601
# 2013-01-17    0.656268
# 2013-01-18   -0.112415
# 2013-01-19    0.917509
# 2013-01-20    0.818295
# 2013-01-21   -0.302383
# 2013-01-22    1.834391
# 2013-01-23    0.366789
# 2013-01-24    0.490921
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.171542  0.085687 -0.791265  1.843809
# 2013-01-02 -1.027656 -0.570549 -0.028820 -0.772222
# 2013-01-03 -0.604392  0.599069  0.649404 -0.882147

# %%
superlongvariablenamethatishardtotype = 1

# %%
df.describe()
# Out:
#                A          B          C          D
# count  24.000000  24.000000  24.000000  24.000000
# mean    0.144446  -0.055121   0.085492  -0.257555
# std     0.944133   0.897679   0.868507   1.129975
# min    -2.774914  -1.823587  -1.555579  -2.768576
# 25%    -0.273157  -0.625750  -0.549240  -0.936448
# 50%     0.398262   0.045751   0.130842  -0.497083
# 75%     0.784611   0.444934   0.670602   0.652452
# max     1.834391   2.075397   2.105619   1.843809

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A   -0.171542   -1.027656   -0.604392   -2.774914   -0.007489   -0.241826
# B    0.085687   -0.570549    0.599069    2.075397    0.158310   -1.173417
# C   -0.791265   -0.028820    0.649404    0.220806   -0.535388   -0.718901
# D    1.843809   -0.772222   -0.882147   -2.768576   -0.651929   -0.792095
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10  ...  2013-01-15  \
# A    0.773383    1.073535    0.974921   -1.164131  ...    0.624493
# B   -1.823587   -0.285984   -0.000657   -0.791354  ...    0.504429
# C   -0.483984    0.972434    0.734197    0.245642  ...    1.375158
# D   -0.096229   -1.099351    0.991177    0.154251  ...   -0.460327
#
#    2013-01-16  2013-01-17  2013-01-18  2013-01-19  2013-01-20  2013-01-21  \
# A   -0.287601    0.656268   -0.112415    0.917509    0.818295   -0.302383
# B    0.687064   -0.196738   -0.858127    1.105632   -0.089097    0.154245
# ...

# %%
df.loc[dates[0], "A"]
# Out:
# -0.1715415144564501

# %%
df_csv = pd.read_csv('hotel_booking_data.csv')

# %%
df_csv.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
type(table_MN)
# Out:
# list

# %%
table_MN[12]
# Out:
#               vteProtected areas of Minnesota  \
# 0                                    National
# 1                                       Parks
# 2                                   Monuments
# 3                                      Rivers
# 4                               Scenic Trails
# 5                            Wildlife Refuges
# 6                Wetland Management Districts
# 7                                     Forests
# 8                           Natural Landmarks
# 9                                  Wilderness
# 10                                      State
# 11                                      Parks
# 12                           Recreation Areas
# 13                                   Waysides
# 14                                    Forests
# 15               Scientific and Natural Areas
# 16                                      Local
# 17                                      Parks
# 18                                      Other
# ...

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Election results from statewide races')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# e:\TKH Git\Innovation Fellowship 2023\tkh_if_dsc_23_student\1.06\11_06\pandasfun.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/TKH%20Git/Innovation%20Fellowship%202023/tkh_if_dsc_23_student/1.06/11_06/pandasfun.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Election results from statewide races')
#
# File c:\Users\lutim\anaconda3\envs\phase1\lib\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
# ...

# %%
df_nan = pd.DataFrame([np.nan, "NaN"])

# %%
df_nan
# Out:
#      0
# 0  NaN
# 1  NaN

# %%
df_nan.isna().sum()
# Out:
# 0    1
# dtype: int64

# %%
df_fill = df_nan.fillna(0)

# %%
df_fill
# Out:
#      0
# 0    0
# 1  NaN

# %%
df_nan.fillna(0, inplace=True)

# %%
df_nan
# Out:
#      0
# 0    0
# 1  NaN
